# %%
a=2
a+=5
print(a)
a-=1
print(a)
a*=2
print(a)
a/=2
print(a)
a**=3
print(a)
a%=7
a//=5
a
# Out:
# 7
# 6
# 12
# 6.0
# 216.0
# 1.0

# %%
b=5
print(b)
b^=2
print(b)
b&=3
print(b)
b|=3
print(b)
b>>=3
b<<=3
b
# Out:
# 5
# 7
# 3
# 3
# 0

# %% [markdown]
# #  operators

# %%
t1=('AAFT')
print(t1)
# Out:
# AAFT

# %%
print(type(t1))
# Out:
# <class 'str'>

# %%
t1=('AAFT',)
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2=(2,)
print(type(t2))
# Out:
# <class 'int'>

# %%
# for single element (,) comma will be used define tuple datatype.

# %%
thistuple = ('banana','kiwi','orange')
print(thistuple[2])
# Out:
# orange

# %%
thistuple[0]
# Out:
# 'banana'

# %%
t2,dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-831a3c9de686> in <cell line: 1>()
# ----> 1 t2,dtypes
#
# NameError: name 'dtypes' is not defined

# %%
thistuple[:2]
# Out:
# ('banana', 'kiwi')

# %% [markdown]
# #  tuple is unchangeable

# %%
# tuple is unchangeable

# %%
a=(1,2,3)
b=list(a)
b[2]=4
b
# Out:
# [1, 2, 4]

# %%
c=tuple(b)
print(type(c))
c
# Out:
# <class 'tuple'>
# (1, 2, 4)

# %%
c=("apple")
print(type(c))
d=("kiwi",)
print(type(d))
# Out:
# <class 'str'>
# <class 'tuple'>

# %%
fruits=["banana","kiwi","oraange","apple"]
u,x,y,z=fruits
print(u,x,y,z)
print(u)
print(x)
print(y)
print(z)
# Out:
# banana kiwi oraange apple
# banana
# kiwi
# oraange
# apple

# %%
t1=("kiwi",33,True,87,"apple")
print(t1)
# Out:
# ('kiwi', 33, True, 87, 'apple')

# %%
print(t1[1:4])
# Out:
# (33, True, 87)

# %%
print(t1[:4])
# Out:
# ('kiwi', 33, True, 87)

# %%
print(t1[1:])
# Out:
# (33, True, 87, 'apple')

# %%
print(t1[-4:-1])
# Out:
# (33, True, 87)

# %%
t2=list(t1)
t2[1]="berry"
t2
# Out:
# ['kiwi', 'berry', True, 87, 'apple']

# %%
t3=tuple(t2)
print(type(t3))
# Out:
# <class 'tuple'>
